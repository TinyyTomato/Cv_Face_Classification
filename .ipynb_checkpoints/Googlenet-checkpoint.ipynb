# %%
import torch.nn as nn
import torch
from torchvision import transforms, datasets, utils
import os
import sys
import json
import time
import torch
import torch.nn as nn
from torchvision import transforms, datasets, utils
import matplotlib.pyplot as plt
import numpy as np
import torch.optim as optim
from tqdm import tqdm
from torchsummaryX import summary
from PIL import Image
from torchvision import transforms
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
class GoogLeNet(nn.Module):
    def __init__(self, num_classes=1000, aux_logits=True, init_weights=False):
        super(GoogLeNet, self).__init__()
        self.aux_logits = aux_logits

        self.conv1 = BasicConv2d(3, 64, kernel_size=7, stride=2, padding=3)
        self.maxpool1 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=3, padding=1)
        self.maxpool2 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)

        if self.aux_logits:
            self.aux1 = InceptionAux(512, num_classes)
            self.aux2 = InceptionAux(528, num_classes)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, num_classes)
        if init_weights:
            self._initialize_weights()

    def forward(self, x):
        # N x 3 x 224 x 224
        x = self.conv1(x)
        # N x 64 x 112 x 112
        x = self.maxpool1(x)
        # N x 64 x 56 x 56
        x = self.conv2(x)
        # N x 64 x 56 x 56
        x = self.conv3(x)
        # N x 192 x 56 x 56
        x = self.maxpool2(x)

        # N x 192 x 28 x 28
        x = self.inception3a(x)
        # N x 256 x 28 x 28
        x = self.inception3b(x)
        # N x 480 x 28 x 28
        x = self.maxpool3(x)
        # N x 480 x 14 x 14
        x = self.inception4a(x)
        # N x 512 x 14 x 14
        if self.training and self.aux_logits:    # eval model lose this layer
            aux1 = self.aux1(x)

        x = self.inception4b(x)
        # N x 512 x 14 x 14
        x = self.inception4c(x)
        # N x 512 x 14 x 14
        x = self.inception4d(x)
        # N x 528 x 14 x 14
        if self.training and self.aux_logits:    # eval model lose this layer
            aux2 = self.aux2(x)

        x = self.inception4e(x)
        # N x 832 x 14 x 14
        x = self.maxpool4(x)
        # N x 832 x 7 x 7
        x = self.inception5a(x)
        # N x 832 x 7 x 7
        x = self.inception5b(x)
        # N x 1024 x 7 x 7

        x = self.avgpool(x)
        # N x 1024 x 1 x 1
        x = torch.flatten(x, 1)
        # N x 1024
        x = self.dropout(x)
        x = self.fc(x)
        # N x 2
        if self.training and self.aux_logits:   # eval model lose this layer
            return x, aux2, aux1
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)


class Inception(nn.Module):
    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()

        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)   # 保证输出大小等于输入大小
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=5, padding=2)   # 保证输出大小等于输入大小
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        outputs = [branch1, branch2, branch3, branch4]
        return torch.cat(outputs, 1)


class InceptionAux(nn.Module):
    def __init__(self, in_channels, num_classes):
        super(InceptionAux, self).__init__()
        self.averagePool = nn.AvgPool2d(kernel_size=5, stride=3)
        self.conv = BasicConv2d(in_channels, 128, kernel_size=1)  # output[batch, 128, 4, 4]

        self.fc1 = nn.Linear(2048, 1024)
        self.fc2 = nn.Linear(1024, num_classes)

    def forward(self, x):
        # aux1: N x 512 x 14 x 14, aux2: N x 528 x 14 x 14
        x = self.averagePool(x)
        # aux1: N x 512 x 4 x 4, aux2: N x 528 x 4 x 4
        x = self.conv(x)
        # N x 128 x 4 x 4
        x = torch.flatten(x, 1)
        x = F.dropout(x, 0.5, training=self.training)
        # N x 2048
        x = F.relu(self.fc1(x), inplace=True)
        x = F.dropout(x, 0.5, training=self.training)
        # N x 1024
        x = self.fc2(x)
        # N x num_classes
        return x


class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, **kwargs)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.conv(x)
        x = self.relu(x)
        return x

# %%
def train():
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("using {} device.".format(device))

    data_transform = {
        "train": transforms.Compose([transforms.Resize((224, 224)),
                                     transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]),
        "val": transforms.Compose([transforms.Resize((224, 224)),  
                                   transforms.ToTensor(),
                                   transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])}

    data_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))  # get data root path
    image_path = os.path.join(data_root, "data_set", "face_data")  
    assert os.path.exists(image_path), "{} path does not exist.".format(image_path)
    train_dataset = datasets.ImageFolder(root=os.path.join(image_path, "train"),
                                         transform=data_transform["train"])
    train_num = len(train_dataset)

    face_list = train_dataset.class_to_idx
    cla_dict = dict((val, key) for key, val in face_list.items())
    # write dict into json file
    json_str = json.dumps(cla_dict, indent=4)
    with open('class_indices.json', 'w') as json_file:
        json_file.write(json_str)
    batch_size = 32
    nw =0
    print('Using {} dataloader workers every process'.format(nw))

    train_loader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=batch_size, shuffle=True,
                                               num_workers=nw)

    validate_dataset = datasets.ImageFolder(root=os.path.join(image_path, "val"),
                                            transform=data_transform["val"])
    val_num = len(validate_dataset)
    validate_loader = torch.utils.data.DataLoader(validate_dataset,
                                                  batch_size=batch_size, shuffle=False,
                                                  num_workers=nw)

    print("using {} images for training, {} images for validation.".format(train_num,
                                                                           val_num))


    net = GoogLeNet(num_classes=2, aux_logits=True, init_weights=True)
    net.to(device)
    summary(net,torch.zeros(1,3,224,224))
    loss_function = nn.CrossEntropyLoss()
    optimizer = optim.Adam(net.parameters(), lr=0.0002)

    epochs = 30
    best_acc = 0.0
    save_path = './googleNet.pth'
    train_steps = len(train_loader)
    timlist=[]
    t_loss=[]
    val_a=[]
    nowtim=time.perf_counter()
    timlist.append(nowtim)
    val_a.append(0)
    t_loss.append(1)
    for epoch in range(epochs):
        # train
        net.train()
        running_loss = 0.0
        train_bar = tqdm(train_loader, file=sys.stdout)
        for step, data in enumerate(train_bar):
            images, labels = data
            optimizer.zero_grad()
            logits, aux_logits2, aux_logits1 = net(images.to(device))
            loss0 = loss_function(logits, labels.to(device))
            loss1 = loss_function(aux_logits1, labels.to(device))
            loss2 = loss_function(aux_logits2, labels.to(device))
            loss = loss0 + loss1 * 0.3 + loss2 * 0.3
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()

            train_bar.desc = "train epoch[{}/{}] loss:{:.3f}".format(epoch + 1,
                                                                     epochs,
                                                                     loss)

        # validate
        net.eval()
        acc = 0.0  # accumulate accurate number / epoch
        with torch.no_grad():
            val_bar = tqdm(validate_loader, file=sys.stdout)
            for val_data in val_bar:
                val_images, val_labels = val_data
                outputs = net(val_images.to(device))  # eval model only have last output layer
                predict_y = torch.max(outputs, dim=1)[1]
                acc += torch.eq(predict_y, val_labels.to(device)).sum().item()

        val_accurate = acc / val_num
        tim=time.perf_counter()
        print('[epoch %d] train_loss: %.3f  val_accuracy: %.3f time:%.3lf' %
              (epoch + 1, running_loss / train_steps, val_accurate,tim-nowtim))
        nowtim=tim
        timlist.append(nowtim)
        val_a.append(val_accurate)
        t_loss.append(running_loss / train_steps)
        if val_accurate > best_acc:
            best_acc = val_accurate
            torch.save(net.state_dict(), save_path)
    print('Finished Training')
    return timlist,val_a,t_loss

# %%
def test():
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    data_transform = transforms.Compose(
        [transforms.Resize((224, 224)),
         transforms.ToTensor(),
         transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

    # load image
    path_img = './testimages/'
    ls = os.listdir(path_img)
    pre=[]
    for i in ls:
        img = Image.open(f"./testimages/{i}")
    # [N, C, H, W]
        img = data_transform(img)
        # expand batch dimension
        img = torch.unsqueeze(img, dim=0)

        # read class_indict
        json_path = './class_indices.json'
        assert os.path.exists(json_path), "file: '{}' dose not exist.".format(json_path)

        with open(json_path, "r") as f:
            class_indict = json.load(f)

        # create model
        model = GoogLeNet(num_classes=2, aux_logits=False).to(device)

        # load model weights
        weights_path = "./googleNet.pth"
        assert os.path.exists(weights_path), "file: '{}' dose not exist.".format(weights_path)
        missing_keys, unexpected_keys = model.load_state_dict(torch.load(weights_path, map_location=device),
                                                              strict=False)

        model.eval()
        with torch.no_grad():
            # predict class
            output = torch.squeeze(model(img.to(device))).cpu()
            predict = torch.softmax(output, dim=0)
            predict_cla = torch.argmax(predict).numpy()

        print_res = "class: {}   prob: {:.3}".format(class_indict[str(predict_cla)],
                                                     predict[predict_cla].numpy())

        if class_indict[str(predict_cla)]=='male':
            pre.append(1)
        else:
            pre.append(-1)

    return pre

# %%
train()
# Out:
# using cpu device.
# Using 0 dataloader workers every process
# using 2701 images for training, 299 images for validation.
# ==================================================================================================
#                                            Kernel Shape       Output Shape  \
# Layer
# 0_conv1.Conv2d_conv                       [3, 64, 7, 7]  [1, 64, 112, 112]
# 1_conv1.ReLU_relu                                     -  [1, 64, 112, 112]
# 2_maxpool1                                            -    [1, 64, 56, 56]
# 3_conv2.Conv2d_conv                      [64, 64, 1, 1]    [1, 64, 56, 56]
# 4_conv2.ReLU_relu                                     -    [1, 64, 56, 56]
# 5_conv3.Conv2d_conv                     [64, 192, 3, 3]   [1, 192, 56, 56]
# 6_conv3.ReLU_relu                                     -   [1, 192, 56, 56]
# 7_maxpool2                                            -   [1, 192, 28, 28]
# 8_inception3a.branch1.Conv2d_conv       [192, 64, 1, 1]    [1, 64, 28, 28]
# 9_inception3a.branch1.ReLU_relu                       -    [1, 64, 28, 28]
# 10_inception3a.branch2.0.Conv2d_conv    [192, 96, 1, 1]    [1, 96, 28, 28]
# 11_inception3a.branch2.0.ReLU_relu                    -    [1, 96, 28, 28]
# 12_inception3a.branch2.1.Conv2d_conv    [96, 128, 3, 3]   [1, 128, 28, 28]
# 13_inception3a.branch2.1.ReLU_relu                    -   [1, 128, 28, 28]
# 14_inception3a.branch3.0.Conv2d_conv    [192, 16, 1, 1]    [1, 16, 28, 28]
# 15_inception3a.branch3.0.ReLU_relu                    -    [1, 16, 28, 28]
# 16_inception3a.branch3.1.Conv2d_conv     [16, 32, 5, 5]    [1, 32, 28, 28]
# 17_inception3a.branch3.1.ReLU_relu                    -    [1, 32, 28, 28]
# 18_inception3a.branch4.MaxPool2d_0                    -   [1, 192, 28, 28]
# 19_inception3a.branch4.1.Conv2d_conv    [192, 32, 1, 1]    [1, 32, 28, 28]
# 20_inception3a.branch4.1.ReLU_relu                    -    [1, 32, 28, 28]
# 21_inception3b.branch1.Conv2d_conv     [256, 128, 1, 1]   [1, 128, 28, 28]
# 22_inception3b.branch1.ReLU_relu                      -   [1, 128, 28, 28]
# 23_inception3b.branch2.0.Conv2d_conv   [256, 128, 1, 1]   [1, 128, 28, 28]
# 24_inception3b.branch2.0.ReLU_relu                    -   [1, 128, 28, 28]
# 25_inception3b.branch2.1.Conv2d_conv   [128, 192, 3, 3]   [1, 192, 28, 28]
# 26_inception3b.branch2.1.ReLU_relu                    -   [1, 192, 28, 28]
# 27_inception3b.branch3.0.Conv2d_conv    [256, 32, 1, 1]    [1, 32, 28, 28]
# 28_inception3b.branch3.0.ReLU_relu                    -    [1, 32, 28, 28]
# 29_inception3b.branch3.1.Conv2d_conv     [32, 96, 5, 5]    [1, 96, 28, 28]
# 30_inception3b.branch3.1.ReLU_relu                    -    [1, 96, 28, 28]
# 31_inception3b.branch4.MaxPool2d_0                    -   [1, 256, 28, 28]
# 32_inception3b.branch4.1.Conv2d_conv    [256, 64, 1, 1]    [1, 64, 28, 28]
# 33_inception3b.branch4.1.ReLU_relu                    -    [1, 64, 28, 28]
# 34_maxpool3                                           -   [1, 480, 14, 14]
# 35_inception4a.branch1.Conv2d_conv     [480, 192, 1, 1]   [1, 192, 14, 14]
# 36_inception4a.branch1.ReLU_relu                      -   [1, 192, 14, 14]
# 37_inception4a.branch2.0.Conv2d_conv    [480, 96, 1, 1]    [1, 96, 14, 14]
# 38_inception4a.branch2.0.ReLU_relu                    -    [1, 96, 14, 14]
# 39_inception4a.branch2.1.Conv2d_conv    [96, 208, 3, 3]   [1, 208, 14, 14]
# 40_inception4a.branch2.1.ReLU_relu                    -   [1, 208, 14, 14]
# 41_inception4a.branch3.0.Conv2d_conv    [480, 16, 1, 1]    [1, 16, 14, 14]
# 42_inception4a.branch3.0.ReLU_relu                    -    [1, 16, 14, 14]
# 43_inception4a.branch3.1.Conv2d_conv     [16, 48, 5, 5]    [1, 48, 14, 14]
# 44_inception4a.branch3.1.ReLU_relu                    -    [1, 48, 14, 14]
# 45_inception4a.branch4.MaxPool2d_0                    -   [1, 480, 14, 14]
# 46_inception4a.branch4.1.Conv2d_conv    [480, 64, 1, 1]    [1, 64, 14, 14]
# 47_inception4a.branch4.1.ReLU_relu                    -    [1, 64, 14, 14]
# 48_aux1.AvgPool2d_averagePool                         -     [1, 512, 4, 4]
# 49_aux1.conv.Conv2d_conv               [512, 128, 1, 1]     [1, 128, 4, 4]
# 50_aux1.conv.ReLU_relu                                -     [1, 128, 4, 4]
# 51_aux1.Linear_fc1                         [2048, 1024]          [1, 1024]
# 52_aux1.Linear_fc2                            [1024, 2]             [1, 2]
# 53_inception4b.branch1.Conv2d_conv     [512, 160, 1, 1]   [1, 160, 14, 14]
# 54_inception4b.branch1.ReLU_relu                      -   [1, 160, 14, 14]
# 55_inception4b.branch2.0.Conv2d_conv   [512, 112, 1, 1]   [1, 112, 14, 14]
# 56_inception4b.branch2.0.ReLU_relu                    -   [1, 112, 14, 14]
# 57_inception4b.branch2.1.Conv2d_conv   [112, 224, 3, 3]   [1, 224, 14, 14]
# 58_inception4b.branch2.1.ReLU_relu                    -   [1, 224, 14, 14]
# 59_inception4b.branch3.0.Conv2d_conv    [512, 24, 1, 1]    [1, 24, 14, 14]
# 60_inception4b.branch3.0.ReLU_relu                    -    [1, 24, 14, 14]
# 61_inception4b.branch3.1.Conv2d_conv     [24, 64, 5, 5]    [1, 64, 14, 14]
# 62_inception4b.branch3.1.ReLU_relu                    -    [1, 64, 14, 14]
# 63_inception4b.branch4.MaxPool2d_0                    -   [1, 512, 14, 14]
# 64_inception4b.branch4.1.Conv2d_conv    [512, 64, 1, 1]    [1, 64, 14, 14]
# 65_inception4b.branch4.1.ReLU_relu                    -    [1, 64, 14, 14]
# 66_inception4c.branch1.Conv2d_conv     [512, 128, 1, 1]   [1, 128, 14, 14]
# 67_inception4c.branch1.ReLU_relu                      -   [1, 128, 14, 14]
# 68_inception4c.branch2.0.Conv2d_conv   [512, 128, 1, 1]   [1, 128, 14, 14]
# 69_inception4c.branch2.0.ReLU_relu                    -   [1, 128, 14, 14]
# 70_inception4c.branch2.1.Conv2d_conv   [128, 256, 3, 3]   [1, 256, 14, 14]
# 71_inception4c.branch2.1.ReLU_relu                    -   [1, 256, 14, 14]
# 72_inception4c.branch3.0.Conv2d_conv    [512, 24, 1, 1]    [1, 24, 14, 14]
# 73_inception4c.branch3.0.ReLU_relu                    -    [1, 24, 14, 14]
# 74_inception4c.branch3.1.Conv2d_conv     [24, 64, 5, 5]    [1, 64, 14, 14]
# 75_inception4c.branch3.1.ReLU_relu                    -    [1, 64, 14, 14]
# 76_inception4c.branch4.MaxPool2d_0                    -   [1, 512, 14, 14]
# 77_inception4c.branch4.1.Conv2d_conv    [512, 64, 1, 1]    [1, 64, 14, 14]
# 78_inception4c.branch4.1.ReLU_relu                    -    [1, 64, 14, 14]
# 79_inception4d.branch1.Conv2d_conv     [512, 112, 1, 1]   [1, 112, 14, 14]
# 80_inception4d.branch1.ReLU_relu                      -   [1, 112, 14, 14]
# 81_inception4d.branch2.0.Conv2d_conv   [512, 144, 1, 1]   [1, 144, 14, 14]
# 82_inception4d.branch2.0.ReLU_relu                    -   [1, 144, 14, 14]
# 83_inception4d.branch2.1.Conv2d_conv   [144, 288, 3, 3]   [1, 288, 14, 14]
# 84_inception4d.branch2.1.ReLU_relu                    -   [1, 288, 14, 14]
# 85_inception4d.branch3.0.Conv2d_conv    [512, 32, 1, 1]    [1, 32, 14, 14]
# 86_inception4d.branch3.0.ReLU_relu                    -    [1, 32, 14, 14]
# 87_inception4d.branch3.1.Conv2d_conv     [32, 64, 5, 5]    [1, 64, 14, 14]
# 88_inception4d.branch3.1.ReLU_relu                    -    [1, 64, 14, 14]
# 89_inception4d.branch4.MaxPool2d_0                    -   [1, 512, 14, 14]
# 90_inception4d.branch4.1.Conv2d_conv    [512, 64, 1, 1]    [1, 64, 14, 14]
# 91_inception4d.branch4.1.ReLU_relu                    -    [1, 64, 14, 14]
# 92_aux2.AvgPool2d_averagePool                         -     [1, 528, 4, 4]
# 93_aux2.conv.Conv2d_conv               [528, 128, 1, 1]     [1, 128, 4, 4]
# 94_aux2.conv.ReLU_relu                                -     [1, 128, 4, 4]
# 95_aux2.Linear_fc1                         [2048, 1024]          [1, 1024]
# 96_aux2.Linear_fc2                            [1024, 2]             [1, 2]
# 97_inception4e.branch1.Conv2d_conv     [528, 256, 1, 1]   [1, 256, 14, 14]
# 98_inception4e.branch1.ReLU_relu                      -   [1, 256, 14, 14]
# 99_inception4e.branch2.0.Conv2d_conv   [528, 160, 1, 1]   [1, 160, 14, 14]
# 100_inception4e.branch2.0.ReLU_relu                   -   [1, 160, 14, 14]
# 101_inception4e.branch2.1.Conv2d_conv  [160, 320, 3, 3]   [1, 320, 14, 14]
# 102_inception4e.branch2.1.ReLU_relu                   -   [1, 320, 14, 14]
# 103_inception4e.branch3.0.Conv2d_conv   [528, 32, 1, 1]    [1, 32, 14, 14]
# 104_inception4e.branch3.0.ReLU_relu                   -    [1, 32, 14, 14]
# 105_inception4e.branch3.1.Conv2d_conv   [32, 128, 5, 5]   [1, 128, 14, 14]
# 106_inception4e.branch3.1.ReLU_relu                   -   [1, 128, 14, 14]
# 107_inception4e.branch4.MaxPool2d_0                   -   [1, 528, 14, 14]
# 108_inception4e.branch4.1.Conv2d_conv  [528, 128, 1, 1]   [1, 128, 14, 14]
# 109_inception4e.branch4.1.ReLU_relu                   -   [1, 128, 14, 14]
# 110_maxpool4                                          -     [1, 832, 7, 7]
# 111_inception5a.branch1.Conv2d_conv    [832, 256, 1, 1]     [1, 256, 7, 7]
# 112_inception5a.branch1.ReLU_relu                     -     [1, 256, 7, 7]
# 113_inception5a.branch2.0.Conv2d_conv  [832, 160, 1, 1]     [1, 160, 7, 7]
# 114_inception5a.branch2.0.ReLU_relu                   -     [1, 160, 7, 7]
# 115_inception5a.branch2.1.Conv2d_conv  [160, 320, 3, 3]     [1, 320, 7, 7]
# 116_inception5a.branch2.1.ReLU_relu                   -     [1, 320, 7, 7]
# 117_inception5a.branch3.0.Conv2d_conv   [832, 32, 1, 1]      [1, 32, 7, 7]
# 118_inception5a.branch3.0.ReLU_relu                   -      [1, 32, 7, 7]
# 119_inception5a.branch3.1.Conv2d_conv   [32, 128, 5, 5]     [1, 128, 7, 7]
# 120_inception5a.branch3.1.ReLU_relu                   -     [1, 128, 7, 7]
# 121_inception5a.branch4.MaxPool2d_0                   -     [1, 832, 7, 7]
# 122_inception5a.branch4.1.Conv2d_conv  [832, 128, 1, 1]     [1, 128, 7, 7]
# 123_inception5a.branch4.1.ReLU_relu                   -     [1, 128, 7, 7]
# 124_inception5b.branch1.Conv2d_conv    [832, 384, 1, 1]     [1, 384, 7, 7]
# 125_inception5b.branch1.ReLU_relu                     -     [1, 384, 7, 7]
# 126_inception5b.branch2.0.Conv2d_conv  [832, 192, 1, 1]     [1, 192, 7, 7]
# 127_inception5b.branch2.0.ReLU_relu                   -     [1, 192, 7, 7]
# 128_inception5b.branch2.1.Conv2d_conv  [192, 384, 3, 3]     [1, 384, 7, 7]
# 129_inception5b.branch2.1.ReLU_relu                   -     [1, 384, 7, 7]
# 130_inception5b.branch3.0.Conv2d_conv   [832, 48, 1, 1]      [1, 48, 7, 7]
# 131_inception5b.branch3.0.ReLU_relu                   -      [1, 48, 7, 7]
# 132_inception5b.branch3.1.Conv2d_conv   [48, 128, 5, 5]     [1, 128, 7, 7]
# 133_inception5b.branch3.1.ReLU_relu                   -     [1, 128, 7, 7]
# 134_inception5b.branch4.MaxPool2d_0                   -     [1, 832, 7, 7]
# 135_inception5b.branch4.1.Conv2d_conv  [832, 128, 1, 1]     [1, 128, 7, 7]
# 136_inception5b.branch4.1.ReLU_relu                   -     [1, 128, 7, 7]
# 137_avgpool                                           -    [1, 1024, 1, 1]
# 138_dropout                                           -          [1, 1024]
# 139_fc                                        [1024, 2]             [1, 2]
#
#                                           Params    Mult-Adds
# Layer
# 0_conv1.Conv2d_conv                       9.472k  118.013952M
# 1_conv1.ReLU_relu                              -            -
# 2_maxpool1                                     -            -
# 3_conv2.Conv2d_conv                        4.16k   12.845056M
# 4_conv2.ReLU_relu                              -            -
# 5_conv3.Conv2d_conv                     110.784k  346.816512M
# 6_conv3.ReLU_relu                              -            -
# 7_maxpool2                                     -            -
# 8_inception3a.branch1.Conv2d_conv        12.352k    9.633792M
# 9_inception3a.branch1.ReLU_relu                -            -
# 10_inception3a.branch2.0.Conv2d_conv     18.528k   14.450688M
# 11_inception3a.branch2.0.ReLU_relu             -            -
# 12_inception3a.branch2.1.Conv2d_conv     110.72k   86.704128M
# 13_inception3a.branch2.1.ReLU_relu             -            -
# 14_inception3a.branch3.0.Conv2d_conv      3.088k    2.408448M
# 15_inception3a.branch3.0.ReLU_relu             -            -
# 16_inception3a.branch3.1.Conv2d_conv     12.832k     10.0352M
# 17_inception3a.branch3.1.ReLU_relu             -            -
# 18_inception3a.branch4.MaxPool2d_0             -            -
# 19_inception3a.branch4.1.Conv2d_conv      6.176k    4.816896M
# 20_inception3a.branch4.1.ReLU_relu             -            -
# 21_inception3b.branch1.Conv2d_conv       32.896k   25.690112M
# 22_inception3b.branch1.ReLU_relu               -            -
# 23_inception3b.branch2.0.Conv2d_conv     32.896k   25.690112M
# 24_inception3b.branch2.0.ReLU_relu             -            -
# 25_inception3b.branch2.1.Conv2d_conv    221.376k  173.408256M
# 26_inception3b.branch2.1.ReLU_relu             -            -
# 27_inception3b.branch3.0.Conv2d_conv      8.224k    6.422528M
# 28_inception3b.branch3.0.ReLU_relu             -            -
# 29_inception3b.branch3.1.Conv2d_conv     76.896k     60.2112M
# 30_inception3b.branch3.1.ReLU_relu             -            -
# 31_inception3b.branch4.MaxPool2d_0             -            -
# 32_inception3b.branch4.1.Conv2d_conv     16.448k   12.845056M
# 33_inception3b.branch4.1.ReLU_relu             -            -
# 34_maxpool3                                    -            -
# 35_inception4a.branch1.Conv2d_conv       92.352k    18.06336M
# 36_inception4a.branch1.ReLU_relu               -            -
# 37_inception4a.branch2.0.Conv2d_conv     46.176k     9.03168M
# 38_inception4a.branch2.0.ReLU_relu             -            -
# 39_inception4a.branch2.1.Conv2d_conv     179.92k   35.223552M
# 40_inception4a.branch2.1.ReLU_relu             -            -
# 41_inception4a.branch3.0.Conv2d_conv      7.696k     1.50528M
# 42_inception4a.branch3.0.ReLU_relu             -            -
# 43_inception4a.branch3.1.Conv2d_conv     19.248k      3.7632M
# 44_inception4a.branch3.1.ReLU_relu             -            -
# 45_inception4a.branch4.MaxPool2d_0             -            -
# 46_inception4a.branch4.1.Conv2d_conv     30.784k     6.02112M
# 47_inception4a.branch4.1.ReLU_relu             -            -
# 48_aux1.AvgPool2d_averagePool                  -            -
# 49_aux1.conv.Conv2d_conv                 65.664k    1.048576M
# 50_aux1.conv.ReLU_relu                         -            -
# 51_aux1.Linear_fc1                     2.098176M    2.097152M
# 52_aux1.Linear_fc2                         2.05k       2.048k
# 53_inception4b.branch1.Conv2d_conv        82.08k    16.05632M
# 54_inception4b.branch1.ReLU_relu               -            -
# 55_inception4b.branch2.0.Conv2d_conv     57.456k   11.239424M
# 56_inception4b.branch2.0.ReLU_relu             -            -
# 57_inception4b.branch2.1.Conv2d_conv    226.016k   44.255232M
# 58_inception4b.branch2.1.ReLU_relu             -            -
# 59_inception4b.branch3.0.Conv2d_conv     12.312k    2.408448M
# 60_inception4b.branch3.0.ReLU_relu             -            -
# 61_inception4b.branch3.1.Conv2d_conv     38.464k      7.5264M
# 62_inception4b.branch3.1.ReLU_relu             -            -
# 63_inception4b.branch4.MaxPool2d_0             -            -
# 64_inception4b.branch4.1.Conv2d_conv     32.832k    6.422528M
# 65_inception4b.branch4.1.ReLU_relu             -            -
# 66_inception4c.branch1.Conv2d_conv       65.664k   12.845056M
# 67_inception4c.branch1.ReLU_relu               -            -
# 68_inception4c.branch2.0.Conv2d_conv     65.664k   12.845056M
# 69_inception4c.branch2.0.ReLU_relu             -            -
# 70_inception4c.branch2.1.Conv2d_conv    295.168k   57.802752M
# 71_inception4c.branch2.1.ReLU_relu             -            -
# 72_inception4c.branch3.0.Conv2d_conv     12.312k    2.408448M
# 73_inception4c.branch3.0.ReLU_relu             -            -
# 74_inception4c.branch3.1.Conv2d_conv     38.464k      7.5264M
# 75_inception4c.branch3.1.ReLU_relu             -            -
# 76_inception4c.branch4.MaxPool2d_0             -            -
# 77_inception4c.branch4.1.Conv2d_conv     32.832k    6.422528M
# 78_inception4c.branch4.1.ReLU_relu             -            -
# 79_inception4d.branch1.Conv2d_conv       57.456k   11.239424M
# 80_inception4d.branch1.ReLU_relu               -            -
# 81_inception4d.branch2.0.Conv2d_conv     73.872k   14.450688M
# 82_inception4d.branch2.0.ReLU_relu             -            -
# 83_inception4d.branch2.1.Conv2d_conv    373.536k   73.156608M
# 84_inception4d.branch2.1.ReLU_relu             -            -
# 85_inception4d.branch3.0.Conv2d_conv     16.416k    3.211264M
# 86_inception4d.branch3.0.ReLU_relu             -            -
# 87_inception4d.branch3.1.Conv2d_conv     51.264k     10.0352M
# 88_inception4d.branch3.1.ReLU_relu             -            -
# 89_inception4d.branch4.MaxPool2d_0             -            -
# 90_inception4d.branch4.1.Conv2d_conv     32.832k    6.422528M
# 91_inception4d.branch4.1.ReLU_relu             -            -
# 92_aux2.AvgPool2d_averagePool                  -            -
# 93_aux2.conv.Conv2d_conv                 67.712k    1.081344M
# 94_aux2.conv.ReLU_relu                         -            -
# 95_aux2.Linear_fc1                     2.098176M    2.097152M
# 96_aux2.Linear_fc2                         2.05k       2.048k
# 97_inception4e.branch1.Conv2d_conv      135.424k   26.492928M
# 98_inception4e.branch1.ReLU_relu               -            -
# 99_inception4e.branch2.0.Conv2d_conv      84.64k    16.55808M
# 100_inception4e.branch2.0.ReLU_relu            -            -
# 101_inception4e.branch2.1.Conv2d_conv    461.12k     90.3168M
# 102_inception4e.branch2.1.ReLU_relu            -            -
# 103_inception4e.branch3.0.Conv2d_conv    16.928k    3.311616M
# 104_inception4e.branch3.0.ReLU_relu            -            -
# 105_inception4e.branch3.1.Conv2d_conv   102.528k     20.0704M
# 106_inception4e.branch3.1.ReLU_relu            -            -
# 107_inception4e.branch4.MaxPool2d_0            -            -
# 108_inception4e.branch4.1.Conv2d_conv    67.712k   13.246464M
# 109_inception4e.branch4.1.ReLU_relu            -            -
# 110_maxpool4                                   -            -
# 111_inception5a.branch1.Conv2d_conv     213.248k   10.436608M
# 112_inception5a.branch1.ReLU_relu              -            -
# 113_inception5a.branch2.0.Conv2d_conv    133.28k     6.52288M
# 114_inception5a.branch2.0.ReLU_relu            -            -
# 115_inception5a.branch2.1.Conv2d_conv    461.12k     22.5792M
# 116_inception5a.branch2.1.ReLU_relu            -            -
# 117_inception5a.branch3.0.Conv2d_conv    26.656k    1.304576M
# 118_inception5a.branch3.0.ReLU_relu            -            -
# 119_inception5a.branch3.1.Conv2d_conv   102.528k      5.0176M
# 120_inception5a.branch3.1.ReLU_relu            -            -
# 121_inception5a.branch4.MaxPool2d_0            -            -
# 122_inception5a.branch4.1.Conv2d_conv   106.624k    5.218304M
# 123_inception5a.branch4.1.ReLU_relu            -            -
# 124_inception5b.branch1.Conv2d_conv     319.872k   15.654912M
# 125_inception5b.branch1.ReLU_relu              -            -
# 126_inception5b.branch2.0.Conv2d_conv   159.936k    7.827456M
# 127_inception5b.branch2.0.ReLU_relu            -            -
# 128_inception5b.branch2.1.Conv2d_conv   663.936k   32.514048M
# 129_inception5b.branch2.1.ReLU_relu            -            -
# 130_inception5b.branch3.0.Conv2d_conv    39.984k    1.956864M
# 131_inception5b.branch3.0.ReLU_relu            -            -
# 132_inception5b.branch3.1.Conv2d_conv   153.728k      7.5264M
# 133_inception5b.branch3.1.ReLU_relu            -            -
# 134_inception5b.branch4.MaxPool2d_0            -            -
# 135_inception5b.branch4.1.Conv2d_conv   106.624k    5.218304M
# 136_inception5b.branch4.1.ReLU_relu            -            -
# 137_avgpool                                    -            -
# 138_dropout                                    -            -
# 139_fc                                     2.05k       2.048k
# --------------------------------------------------------------------------------------------------
#                            Totals
# Total params            10.30943M
# Trainable params        10.30943M
# Non-trainable params          0.0
# Mult-Adds             1.58797824G
# ==================================================================================================
# train epoch[1/30] loss:1.442:  18%|█████████▏                                          | 15/85 [00:48<03:52,  3.33s/it]

# %%
pre=test()
path_img = './testimages/'
ls = os.listdir(path_img)
name=[]
for i in ls:
    name.append(i)
import pandas as pd
out_dict = {
    'image_id':list(name),
    'is_male':list(pre)
}
out = pd.DataFrame(out_dict)
out.to_csv('GoogLenet.csv',index=False)
